# %%
from matplotlib import pyplot as plt
import sys
sys.path.append("/home/terrain_flow/")
from toolbox.dataset import Dataset

# %%
dataset = Dataset('/home/data/raw/n44_e006_1arc_v3.tif')

# %%
heightmap = dataset.LoadHeightmap()
plt.imshow(heightmap)
plt.colorbar()
