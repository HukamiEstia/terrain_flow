# %%
import sys
sys.path.append("/home/")
from terrain_flow_python import *

# %%
Hmap = dataUtils.load_heightmap('/home/data/test1.tif')
dataUtils.display_map(Hmap)
# Out:
# <div>
#
#
#             <div id="ca6349b7-903a-44de-8d26-8a42b263f872" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca6349b7-903a-44de-8d26-8a42b263f872")) {
#                     Plotly.newPlot(
#                         'ca6349b7-903a-44de-8d26-8a42b263f872',
# ...
